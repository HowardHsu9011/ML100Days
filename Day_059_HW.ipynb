# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
X.shape
# Out:
# (537, 64)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
pca = PCA(n_components=3).fit_transform(X)
ax = plt.axes(projection='3d')
ax.scatter(pca[:,0]  , pca[: , 1] , pca[: , 2] , c=y)
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score

GDBT = GradientBoostingClassifier(random_state=1)
X_train , X_test , y_train , y_test = train_test_split(X , y , train_size=0.8 , random_state=1)
GDBT.fit(X_train , y_train)
y_pred = GDBT.predict(X_test)
print('Accracy_GDBT = ',accuracy_score(y_test , y_pred))
# Out:
# Accracy_GDBT =  0.9722222222222222

# %%
pca_x = PCA(n_components=3).fit_transform(X_st)
pca_x
X_train , X_test , y_train , y_test = train_test_split(pca_x , y , train_size=0.8 , random_state=1)
GDBT.fit(X_train , y_train)
y_pred = GDBT.predict(X_test)
print('Accracy_GDBT_PCA = ',accuracy_score(y_test , y_pred))
# Out:
# Accracy_GDBT_PCA =  1.0
