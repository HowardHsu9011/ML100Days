# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative
#
# ![image.png](attachment:image.png)

# %%
import os
import keras
from keras.datasets import cifar10

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.np_utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
import tensorflow as tf

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_tp_tn
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def __init__(self, valid_data=(x_test, y_test)):
        self.validation_data = valid_data
        
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_tp", "val_tn"]
        for i in record_items:
            try:
                if i not in self.params["metrics"]:
                    self.params["metrics"].append(i)
            except:
                self.params["metrics"] = i
                
    def on_epoch_end(self, epoch, logs={}, thres = 0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) *1
        
        val_tp = sum(y_true * y_pred)
        val_tn = sum((y_true == 0) & (y_pred == 0))
        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn   
        
rec_tptn = Record_tp_tn()

# %%
import tensorflow as tf
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = tf.keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, epochs = EPOCHS, batch_size = BATCH_SIZE,
          validation_data = (x_test, y_test), shuffle = True,
          callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history["val_tp"]
valid_tn = model.history.history["val_tn"]
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  batch_normalization_9 (Batc  (None, 512)              2048
#  hNormalization)
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/25
# 49/49 [==============================] - 4s 68ms/step - loss: 2.2240 - accuracy: 0.2726 - val_loss: 2.1496 - val_accuracy: 0.1977 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/25
# 49/49 [==============================] - 3s 65ms/step - loss: 1.7404 - accuracy: 0.3932 - val_loss: 1.9696 - val_accuracy: 0.3013 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 3/25
# 49/49 [==============================] - 3s 67ms/step - loss: 1.6156 - accuracy: 0.4339 - val_loss: 1.8204 - val_accuracy: 0.3734 - val_tp: 7.0000 - val_tn: 1000.0000
# Epoch 4/25
# 49/49 [==============================] - 3s 64ms/step - loss: 1.5428 - accuracy: 0.4629 - val_loss: 1.7178 - val_accuracy: 0.4068 - val_tp: 94.0000 - val_tn: 1000.0000
# Epoch 5/25
# 49/49 [==============================] - 3s 68ms/step - loss: 1.4892 - accuracy: 0.4798 - val_loss: 1.6400 - val_accuracy: 0.4270 - val_tp: 226.0000 - val_tn: 1000.0000
# Epoch 6/25
# 49/49 [==============================] - 3s 64ms/step - loss: 1.4441 - accuracy: 0.4968 - val_loss: 1.5878 - val_accuracy: 0.4457 - val_tp: 477.0000 - val_tn: 999.0000
# Epoch 7/25
# 49/49 [==============================] - 3s 63ms/step - loss: 1.4034 - accuracy: 0.5124 - val_loss: 1.5471 - val_accuracy: 0.4553 - val_tp: 693.0000 - val_tn: 998.0000
# Epoch 8/25
# 49/49 [==============================] - 3s 61ms/step - loss: 1.3672 - accuracy: 0.5254 - val_loss: 1.5235 - val_accuracy: 0.4668 - val_tp: 770.0000 - val_tn: 998.0000
# Epoch 9/25
# 49/49 [==============================] - 3s 59ms/step - loss: 1.3349 - accuracy: 0.5370 - val_loss: 1.5052 - val_accuracy: 0.4682 - val_tp: 999.0000 - val_tn: 994.0000
# Epoch 10/25
# 49/49 [==============================] - 3s 60ms/step - loss: 1.3049 - accuracy: 0.5494 - val_loss: 1.4888 - val_accuracy: 0.4746 - val_tp: 1280.0000 - val_tn: 992.0000
# Epoch 11/25
# 49/49 [==============================] - 3s 67ms/step - loss: 1.2769 - accuracy: 0.5579 - val_loss: 1.4754 - val_accuracy: 0.4809 - val_tp: 1910.0000 - val_tn: 987.0000
# Epoch 12/25
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2507 - accuracy: 0.5685 - val_loss: 1.4641 - val_accuracy: 0.4843 - val_tp: 1735.0000 - val_tn: 987.0000
# Epoch 13/25
# 49/49 [==============================] - 3s 71ms/step - loss: 1.2249 - accuracy: 0.5766 - val_loss: 1.4692 - val_accuracy: 0.4850 - val_tp: 1810.0000 - val_tn: 989.0000
# Epoch 14/25
# 49/49 [==============================] - 4s 77ms/step - loss: 1.2022 - accuracy: 0.5866 - val_loss: 1.4676 - val_accuracy: 0.4858 - val_tp: 1907.0000 - val_tn: 984.0000
# Epoch 15/25
# 49/49 [==============================] - 4s 82ms/step - loss: 1.1766 - accuracy: 0.5969 - val_loss: 1.4623 - val_accuracy: 0.4858 - val_tp: 2336.0000 - val_tn: 981.0000
# Epoch 16/25
# 49/49 [==============================] - 5s 97ms/step - loss: 1.1541 - accuracy: 0.6043 - val_loss: 1.4555 - val_accuracy: 0.4906 - val_tp: 1524.0000 - val_tn: 985.0000
# Epoch 17/25
# 49/49 [==============================] - 7s 142ms/step - loss: 1.1325 - accuracy: 0.6124 - val_loss: 1.4530 - val_accuracy: 0.4920 - val_tp: 2257.0000 - val_tn: 979.0000
# Epoch 18/25
# 49/49 [==============================] - 5s 98ms/step - loss: 1.1102 - accuracy: 0.6198 - val_loss: 1.4501 - val_accuracy: 0.4901 - val_tp: 2679.0000 - val_tn: 974.0000
# Epoch 19/25
# 49/49 [==============================] - 4s 78ms/step - loss: 1.0877 - accuracy: 0.6286 - val_loss: 1.4424 - val_accuracy: 0.4954 - val_tp: 2352.0000 - val_tn: 976.0000
# Epoch 20/25
# 49/49 [==============================] - 7s 147ms/step - loss: 1.0656 - accuracy: 0.6365 - val_loss: 1.4459 - val_accuracy: 0.4927 - val_tp: 2018.0000 - val_tn: 979.0000
# Epoch 21/25
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0470 - accuracy: 0.6454 - val_loss: 1.4506 - val_accuracy: 0.4976 - val_tp: 2206.0000 - val_tn: 975.0000
# Epoch 22/25
# 49/49 [==============================] - 7s 142ms/step - loss: 1.0246 - accuracy: 0.6539 - val_loss: 1.4541 - val_accuracy: 0.4899 - val_tp: 2123.0000 - val_tn: 985.0000
# Epoch 23/25
# 49/49 [==============================] - 6s 132ms/step - loss: 1.0056 - accuracy: 0.6606 - val_loss: 1.4498 - val_accuracy: 0.4946 - val_tp: 1686.0000 - val_tn: 982.0000
# Epoch 24/25
# 49/49 [==============================] - 6s 127ms/step - loss: 0.9838 - accuracy: 0.6698 - val_loss: 1.4491 - val_accuracy: 0.4940 - val_tp: 2184.0000 - val_tn: 981.0000
# Epoch 25/25
# 49/49 [==============================] - 6s 128ms/step - loss: 0.9630 - accuracy: 0.6759 - val_loss: 1.4671 - val_accuracy: 0.4948 - val_tp: 2105.0000 - val_tn: 978.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
